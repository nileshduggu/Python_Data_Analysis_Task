# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hellow World")
# Out:
# Hellow World

# %%
country = "India"
total_spend = 6000
if (country == "India") and (total_spend > 5000):
    print("Vip customer :- Apply 20% Discount")
else :
    print ("Regular Customer")
# Out:
# vip customer :- Apply 20% Discount

# %%
has_email = False
has_phone = False

if (has_email == True) or (has_phone == True):
    print("You are Logged In")

else:
    print("Login Failed Plz Provide Valid Email Id  or Valid Phone Number")
# Out:
# Login Failed Plz Provide Valid Email Id  or Valid Phone Number

# %%
is_file_empty = True
if not (is_file_empty):
    print("Processing Files : Data Found")
else :
    print("Error : File is empty cannot process")
# Out:
# Error : File is empty cannot process

# %%
is_file_empty = False

if not (is_file_empty):
    print("Processing Files : Data Found")
else : 
    print("Error : File is Empty cannot Process")
# Out:
# Processing Files : Data Found

# %%
user_role = "staff"
is_banned = "False"

if (user_role == "staff") or (user_role == "Admin") and not (is_banned):
    print("Access Granted")
else :
    print("Access Denied")
# Out:
# Access Granted

# %%
customer_age = 21
salary = 50000

if (customer_age == 21) and (salary >= 50000):
    
    print(" You are Elegible For Credit Card")
else :

    print(" You r Not Eligible For Credit Card BEST OF LUCK FOR NEXT TIME")
# Out:
#  You are Elegible For Credit Card

# %%
is_candidate_degree = True
is_candidate_experienced = False

if (is_candidate_degree == True) or (is_candidate_experienced == True):
    print("Congratulation You r Shortlisted for Interview")
else:
    print("Sorry ur Not Shortlisted Better Luck Next Time")
# Out:
# Congratulation You r Shortlisted for Interview

# %%
maintenance_mode = True

if not (maintenance_mode):
    print("Website Open")
else :
    print("Off ur maintenance mode")
# Out:
# Off ur maintenance mode

# %%
salary = 30000
credit_score = 750
collateral = False

if (salary >= 40000) and (credit_score > 700) or (collateral == True):
    print("You r eligible for loan")
else :
    print("You r not eligible")
# Out:
# You r not eligible

# %%
position = "Supervisor"
projects_completed = 12

if not (position) and (projects_completed >= 12):
    print("Bonus Approved")
else:
    print("Bonus not Approved")
# Out:
# Bonus not Approved

# %%
position = "Manager"
projects_completed = 12
# Ye line bilkul left se shuru hogi
if not (position == "Manager") and (projects_completed >= 12):
        print("Bonus approved") # Ye 1 tab aage
else:
    print("Bonus Not approved") # Ye bhi 1 tab aage
# Out:
# Bonus Not approved
